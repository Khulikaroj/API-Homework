# %% [markdown]
# # Financial Planner Report

# %% [markdown]
# ## Budget Analysis

# %% [markdown]
# **Spending by category:** 64.31% of client's spending in the past 90 days was money transfer. Example of transfer transactions are  interest payment, deposite, or transfer to pay credit card. 19.76% was payment trasactions, some of them were automatic payment transaction. 10.39% was spending on food and drink. Client spent 4.70% and 0.74% on shopping and recreation activities, respectively. Only 0.11% was spent on travel items.

# %% [markdown]
# ![spending by category](Images/spending-by-categary.JPG)

# %% [markdown]
# **Monthly income and expense:** When break down the spending into each month, client spent only USD 506.33 in June. This left client with slightly deficit position on the month's balance where the monthly income is only USD 500 per month. Huge spending happens in July when client spend USD 10,138.91 in total in the month. The amount is merely twice of income this client can make for the whole year at USD 6,000. Projected income is USD 6,085.

# %% [markdown]
# ![monthly expense](Images/monthly-expense.JPG)

# %% [markdown]
# ## Retirement Planning

# %% [markdown]
# **Investment Plan:** Client choose to invest in 60:40 bond/equity portfolio with 30 years of investment period until retire. From simulation, retirement portfolio would yield positive cumulative return at retirement time. Cumulative return over the whole investment horizon could be 8.21-27.10%, with 90% confident interval.

# %% [markdown]
# ![simulated return distribution](Images/simulated-return-distribution.JPG)

# %% [markdown]
# ![projected cumulative return](Images/projected-cumulative-return.JPG)

# %% [markdown]
# With USD 20,000 inital amount for retirement investment, mean of projected return is USD 31,4222.25. Client's retirement investment could yield USD 20,2052.39-48,8738.49 with 80% confidence interval.

# %% [markdown]
# Client plan to withdraw from this retirement investment at the sustain withdrawal rate of 4% per year over 30 years after client retires from work. In worst-case scenario, client could spend only USD 269.40 per year which is far lower than his salary when he retire (USD  6,085 per year). In the best-case scenario, spending per year is USD 651.51, which is still lower than what client can spend before client retires.

# %% [markdown]
# **Disclaimer** Projected return from investment is generated from Monte Carlo using 1-year historical return characteristics. Actual portfolio performance could have large drawdown such as during latest COVID-19 pandemic crisis.

# %% [markdown]
# ![1y historical performance](Images/1y-historical-return.JPG)
